# %% [markdown]
# <a href="https://colab.research.google.com/github/haleemaraza/practice/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student():
  def __init__(self,fullname):
    self.name=fullname
    print("addingg student in database...")

s1 = Student("boran")
print(s1.name)
print("student is added.")
# Out:
# addingg student in database...
# boran
# student is added.

# %%
class Student():
  def __init__(self):
    pass

# %%
class Student():
  clg="abcd" #class attribute
  def __init__(self,name,marks):
    self.name=name
    self.marks=marks #obj attribute
    print("adding student in database...")
s1=Student("boran",100)
print(s1.name,s1.marks)
# Out:
# adding student in database...
# boran 100

# %%
class Student():
  clg="abcd"
  def __init__(self,name,marks):
    self.name=name
    self.marks=marks

  def welcome(self):
    print("welcome",self.name)

  def get_marks(self):
    return(self.marks)

s1=Student("boran",100)
s1.welcome()
print(s1.get_marks())
# Out:
# welcome boran
# 100

# %%
class Student():
  def __init__ (self,name,marks1,marks2,marks3):
    self.name =name
    self.marks1=marks1
    self.marks2=marks2
    self.marks3=marks3

  def welcome(self):
    print('welcome',self.name)

  def marks_avg(self):
    sum=self.marks1 + self.marks2 + self.marks3
    avg =sum/2
    return(avg)


s1 = Student("jing boran",99,98,97)
s1.welcome()
print(s1.marks_avg())
# Out:
# welcome jing boran
# 147.0

# %%
class Student():
  def __init__ (self,name,marks):
    self.name=name
    self.marks=marks

  def get_avg(self):
    sum=0
    for val in self.marks:
      sum+=val
      print("welcome",self.name,"your avg score is:", sum/3)

s1 = Student("jing boran",[100,100,100])
s1.get_avg()
# Out:
# welcome jing boran your avg score is: 33.333333333333336
# welcome jing boran your avg score is: 66.66666666666667
# welcome jing boran your avg score is: 100.0

# %%
class Student():
  def __init__ (self,name,marks):
    self.name=name
    self.marks=marks

  def get_avg(self):
    sum=0
    for val in self.marks:
      sum+=val
    print("welcome",self.name,"your avg score is:", sum/3)

s1 = Student("jing boran",[100,100,100])
s1.get_avg()

s1.name="Luan Nian"
s1.get_avg()
# Out:
# welcome jing boran your avg score is: 100.0
# welcome Luan Nian your avg score is: 100.0

# %%
#static method
class Student():
  def __init__ (self,name,marks):
    self.name=name
    self.marks=marks

  @staticmethod
  def hello():
    print("hello")

  def get_avg(self):
    sum=0
    for val in self.marks:
      sum+=val
    print("welcome",self.name,"your avg score is:", sum/3)

s1 = Student("jing boran",[100,100,100])
s1.hello()
s1.get_avg()

s1.name="Luan Nian"
s1.hello()
s1.get_avg()
# Out:
# hello
# welcome jing boran your avg score is: 100.0
# hello
# welcome Luan Nian your avg score is: 100.0

# %% [markdown]
# **pillar of OOPS**

# %% [markdown]
# **abstraction**
# hiding the implementation details of a class and only showing the essentail features to the user

# %%
class Car():
  def __init__(self):
    self.acc=False
    self.brk=False
    self.clutch=False

  def start(self):
    self.acc=True
    self.clutch=True
    print("car started...")

c1=Car()
c1.start()
# Out:
# car started...

# %% [markdown]
# **encapsulation**
# wrapping data and functions into a single unit(object)

# %%
#static method
class Student():
  def __init__ (self,name,marks):
    self.name=name
    self.marks=marks

  @staticmethod
  def hello():
    print("hello")

  def get_avg(self):
    sum=0
    for val in self.marks:
      sum+=val
    print("welcome",self.name,"your avg score is:", sum/3)

s1 = Student("jing boran",[100,100,100])
s1.hello()
s1.get_avg()

s1.name="Luan Nian"
s1.hello()
s1.get_avg()

del s1.name
# print(s1.name)
# Out:
# hello
# welcome jing boran your avg score is: 100.0
# hello
# welcome Luan Nian your avg score is: 100.0

# %%
#practice
class Account():
  def __init__(self,bal,acc_no):
    self.bal=bal
    self.acc_no=acc_no

  def debit(self,amount):
    self.bal -=amount
    print("Rs",amount,"was debited")
    print("total balance = ",self.get_balance())

  def credit(self,amount):
    self.bal+=amount
    print("Rs",amount,"was cedited")
    print("total balance = ",self.get_balance())

  def get_balance(self):
    return self.bal

acc1 = Account(10000,1889)
acc1.debit(1000)
acc1.credit(900)
# Out:
# Rs 1000 was debited
# total balance =  9000
# Rs 900 was cedited
# total balance =  9900

# %% [markdown]
# private like attributes and methods
# conceptual implementation in python private ttributes n dmethods are ment to be used only within the class and are not accesible from outside the class

# %%
class Account():
  def __init__(self,acc_no,acc_pass):
    self.acc_no=acc_no
    self.__acc_pass=acc_pass

  def reset_pass(self):
    print(self.__acc_pass)

acc1=Account("jddh","1u2812")

# print(acc1.__acc_pass)
print(acc1.acc_no)
# Out:
# jddh

# %%
class Person():
  __name="boran"

  def __hello(self):
    print("hello person!")

  def welcome(self):
    self.__hello()

p1 = Person()
print(p1.welcome())
# Out:
# hello person!
# None

# %% [markdown]
# **INHERITANCE**
# when one class (child/derived) derives the properties and method of another class(parent/base)

# %%
class Car():
  color="balck"

  @staticmethod
  def start():
    print("car started...")

  @staticmethod
  def stop():
    print("car stopted...")

class ToyotaCar(Car):
  def __init__(self,name):
    self.name=name

car1 = ToyotaCar("fortuner")
print(car1.start())
# Out:
# ca started...
# None

# %%
#single inheritance
class Car():
  color="balck"

  @staticmethod
  def start():
    print("car started...")

  @staticmethod
  def stop():
    print("car stopted...")

class ToyotaCar(Car):
  def __init__(self,name):
    self.name=name

car1 = ToyotaCar("fortuner")
print(car1.start())

# %%
#multi-level inheritance
class Car():

  @staticmethod
  def start():
    print("car started...")

  @staticmethod
  def stop():
    print("car stopted...")

class ToyotaCar(Car):
  def __init__(self,name):
    self.name=name

class Fortuner(ToyotaCar):
  def __init__(self, type):
    self.type=type

car1=Fortuner("diesel")
car1.start()
# Out:
# car started...

# %%
#multiple inhertitance
class A:
  varA="welcome to A"

class B:
  varB ="welcome to b"

class C(A,B):
  varC='welcome to C'

c1 = C()
print(c1.varA)
print(c1.varB)
print(c1.varC)
# Out:
# welcome to A
# welcome to b
# welcome to C

# %%
 #super()

class Car:
  def __init__(self,type):
    self.type=type

  @staticmethod
  def start():
    print("car started...")

  @staticmethod
  def stop():
    print("car stopped.")

class ToyotaCar(Car):
  def __init__(self,name,type):
    self.name=name
    super().__init__(type)
    super().start()

car1 = ToyotaCar("prius","electric")
print(car1.name)
print(car1.type)
# Out:
# car started...
# prius
# electric

# %%
# change directly in class
class Person:
  name ="boran"

  def ChangeName(self,name):
    self.name =name
    #self __class__.name="luan nian"
    #Person.name="luan nian"

p1=Person()
p1.ChangeName("luan nian")
print(p1.name)
# Out:
# luan nian

# %%
# classmethod
class Person :
  name="luke"

  @classmethod
  def ChangeName(cls,name):
    cls.name=name
  p1 = Person()
  print(p1.name)
  p1.ChangeName("luan nian")
  print(p1.name)
# Out:
# luke
# luan nian

# %%
# property
class Student:
  def __init__(self,phy,chem,math):
    self.phy=phy
    self.chem=chem
    self.math=math

  @property
  def percentage(self):
    return str((self.math + self.chem + self.phy)/3) + "%"

stu1 = Student(23,54,64)
print(stu1.percentage)
# Out:
# 47.0%

# %% [markdown]
# **POLYMORPHISM**
# when the same operator is allowed to have diff meaning according to the context

# %%
class Complex:
  def __init__(self,real,img):
    self.real=real
    self.img=img

  def ShowNumber(self):
    print(self.real,"i" ,"+", self.img ,"j")

  def __add__(num1,num2):
    newReal=num1.real +num2.real
    newImg =num1.img+num2.img
    return Complex(newReal,newImg)


num1 = Complex(1,2)
num1.ShowNumber()

num2 = Complex(4,5)
num2.ShowNumber()

num3 = num1+num2
num3.ShowNumber()
# Out:
# 1 i + 2 j
# 4 i + 5 j
# 5 i + 7 j

# %%
class Complex:
  def __init__(self,real,img):
    self.real=real
    self.img=img

  def ShowNumber(self):
    print(self.real,"i" ,"+", self.img ,"j")

  def __sub__(num1,num2):
    newReal=num1.real -num2.real
    newImg =num1.img - num2.img
    return Complex(newReal,newImg)


num1 = Complex(1,2)
num1.ShowNumber()

num2 = Complex(4,5)
num2.ShowNumber()

num3 = num1-num2
num3.ShowNumber()
# Out:
# 1 i + 2 j
# 4 i + 5 j
# -3 i + -3 j

# %%
class Circle:
  def __init__(self,radius):
    self.radius=radius

  def Area(self):
    return (22/7) * self.radius **2

  def Permeter(self):
    return 2 * (22/7) * self.radius

c1 = Circle(21)
print(c1.Area())
print(c1.Permeter())
# Out:
# 1386.0
# 132.0

# %%
class Employee():
  def __init__(self,role,dept,salary):
    self.role=role
    self.dept=dept
    self.salary=salary

  def showDetail(self):
    print("role =",self.role )
    print("dept =", self.dept)
    print("salary = ", self.salary)

class Engineer(Employee):
  def __init__(self,name,age ):
    self.name=name
    self.age=age
    super().__init__("accountant","finance",4.2435)

  def showDetail(self):
    print("name =" ,self.name)
    print("age = ",self.age)
    super().showDetail()

# emp1= Employee
# emp1.showDetail()

eng1=Engineer("Elon MUsk",33)
eng1.showDetail()
# Out:
# name = Elon MUsk
# age =  33
# role = accountant
# dept = finance
# salary =  4.2435

# %%
class Order():
  def __init__(self,item,price):
    self.item=item
    self.price=price

  def __gt__(self, ord2):
    return self.price > ord2.price

ord1=Order("jj" ,12)
ord2=Order("djfh",22)

print(ord1>ord2)
# Out:
# False

# %% [markdown]
# MINI **PROJECT**

# %%
import random

target = random.randint(1,100)

while True:
  userChoice=input("enter your random num or quit(Q):")
  if (userChoice == "Q"):
    break

  userChoice=int(userChoice)
  if(userChoice==target):
    print("success!: correct guess")
    break
  elif(userChoice<target):
    print("your num is too samll. choice bigger guess")
  else:
    print("your num is too big. choice smaller num")

print("_____end_-_of_-_game_____")
# Out:
# enter your random num or quit(Q):Q
# _____end_-_of_-_game_____

# %%
import random
import string

pass_len=12
charvalue = string.ascii_letters + string.digits + string.punctuation

password =""
for i in range(pass_len):
  password +=random.choice(charvalue)

print("your password is :" , password)
# Out:
# your password is : Py^eE/lAef~L

# %%
import random
import string

pass_len=10
charval=string.ascii_letters + string.digits + string.punctuation

res = "".join([random.choice(charval) for i in range(pass_len)])
print(res)
# Out:
# ;mnz^1e({@
